# %% [markdown]
# ### Install and import packages

# %%
# %matplotlib inline
from IPython import display
import os
import math
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from sklearn.metrics import *
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator

np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# ### Pre-processing

# %%
#Setting some inital parameters
height, width = 224, 224
batch_size=64

# %%
data_dir = 'brain_tumor_dataset' #change_path

def image_generator(height,width):
    datagen = ImageDataGenerator(
            rescale=1./255., 
            validation_split=0.2,
            )
    train_ds = datagen.flow_from_directory(
            data_dir,
            batch_size=batch_size,
            subset="training",
            #color_mode = 'grayscale',
            shuffle=True,
            class_mode='binary',
            target_size=(height, width),
            classes={'no': 0., 'yes': 1.}
            )
    val_ds = datagen.flow_from_directory(
              data_dir,
              subset="validation",
              #seed=123,
              #color_mode = 'grayscale',
              class_mode='binary',
              target_size=(height, width),
              batch_size=batch_size,
            classes={'no': 0., 'yes': 1.}
            )
    return train_ds, val_ds

train_ds, val_ds = image_generator(height,width)

total_image = np.concatenate([train_ds.labels,val_ds.labels])
print('\n\n',{'No_brain_tumor_cases':len(np.where(total_image==0)[0]),
      'brain_tumor_cases':len(np.where(total_image==1)[0])})
# Out:
# Found 203 images belonging to 2 classes.
# Found 50 images belonging to 2 classes.
#
#
#  {'No_brain_tumor_cases': 98, 'brain_tumor_cases': 155}

# %%
fig, ax = plt.subplots(2, 4, figsize=(10, 7))
fig.suptitle("brain_tumor_pictures")
for k in range(8):
    images, labels = train_ds.next()
    i, j = k//4, k%4
    ax[i, j].imshow(images[0])
    ax[i, j].set_title(f'label {int(labels[0])}')
    ax[i, j].axis('off')
plt.show()

# %% [markdown]
# ### Initial VGG16 Model

# %%
from tensorflow.keras.layers.experimental import preprocessing

tf.keras.backend.clear_session()
input_shape = (height, width, 3)
base_model = tf.keras.applications.vgg16.VGG16(
    weights='imagenet', 
    include_top=False,
    input_shape=input_shape
)
base_model.trainable = False

model_vgg16 = tf.keras.Sequential()
model_vgg16.add(base_model)
model_vgg16.add(tf.keras.layers.Flatten())

model_vgg16.add(tf.keras.layers.Dense(1, activation='sigmoid'))

model_vgg16.compile(loss='binary_crossentropy', 
              optimizer=tf.keras.optimizers.Adam(0.01),
              metrics=['acc'])
model_vgg16.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 1)                 25089
#
# =================================================================
# Total params: 14,739,777
# Trainable params: 25,089
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint('model/vgg16_best.h5', monitor='acc', verbose=1, mode='max',save_best_only=True)
early = tf.keras.callbacks.EarlyStopping(monitor="acc", mode="max",restore_best_weights=True, patience=5)
callbacks_list = [checkpoint,early]

history = model_vgg16.fit(
        train_ds,
        validation_data=val_ds,
        epochs=20, 
        shuffle=True, 
        verbose=True,
        callbacks=callbacks_list)
# Out:
# Epoch 1/20
# 4/4 [==============================] - ETA: 0s - loss: 10.6743 - acc: 0.5961
# Epoch 1: acc improved from -inf to 0.59606, saving model to model\vgg16_best.h5
# 4/4 [==============================] - 31s 10s/step - loss: 10.6743 - acc: 0.5961 - val_loss: 1.3510 - val_acc: 0.7600
# Epoch 2/20
# 4/4 [==============================] - ETA: 0s - loss: 5.1260 - acc: 0.5714
# Epoch 2: acc did not improve from 0.59606
# 4/4 [==============================] - 32s 8s/step - loss: 5.1260 - acc: 0.5714 - val_loss: 1.9538 - val_acc: 0.7600
# Epoch 3/20
# 4/4 [==============================] - ETA: 0s - loss: 3.9759 - acc: 0.7340
# Epoch 3: acc improved from 0.59606 to 0.73399, saving model to model\vgg16_best.h5
# 4/4 [==============================] - 33s 10s/step - loss: 3.9759 - acc: 0.7340 - val_loss: 5.8946 - val_acc: 0.7000
# Epoch 4/20
# 4/4 [==============================] - ETA: 0s - loss: 3.3163 - acc: 0.7783
# Epoch 4: acc improved from 0.73399 to 0.77833, saving model to model\vgg16_best.h5
# 4/4 [==============================] - 33s 8s/step - loss: 3.3163 - acc: 0.7783 - val_loss: 2.4574 - val_acc: 0.7400
# Epoch 5/20
# 4/4 [==============================] - ETA: 0s - loss: 1.9186 - acc: 0.7980
# Epoch 5: acc improved from 0.77833 to 0.79803, saving model to model\vgg16_best.h5
# 4/4 [==============================] - 32s 8s/step - loss: 1.9186 - acc: 0.7980 - val_loss: 2.8128 - val_acc: 0.6600
# Epoch 6/20
# 4/4 [==============================] - ETA: 0s - loss: 1.4417 - acc: 0.8473
# Epoch 6: acc improved from 0.79803 to 0.84729, saving model to model\vgg16_best.h5
# 4/4 [==============================] - 33s 8s/step - loss: 1.4417 - acc: 0.8473 - val_loss: 3.8083 - val_acc: 0.7800
# Epoch 7/20
# 4/4 [==============================] - ETA: 0s - loss: 1.9977 - acc: 0.8227
# Epoch 7: acc did not improve from 0.84729
# 4/4 [==============================] - 32s 8s/step - loss: 1.9977 - acc: 0.8227 - val_loss: 3.1233 - val_acc: 0.7800
# Epoch 8/20
# 4/4 [==============================] - ETA: 0s - loss: 0.6095 - acc: 0.8916
# Epoch 8: acc improved from 0.84729 to 0.89163, saving model to model\vgg16_best.h5
# 4/4 [==============================] - 33s 8s/step - loss: 0.6095 - acc: 0.8916 - val_loss: 1.7223 - val_acc: 0.8000
# Epoch 9/20
# 4/4 [==============================] - ETA: 0s - loss: 0.6575 - acc: 0.8670
# Epoch 9: acc did not improve from 0.89163
# 4/4 [==============================] - 33s 10s/step - loss: 0.6575 - acc: 0.8670 - val_loss: 1.5168 - val_acc: 0.7800
# Epoch 10/20
# 4/4 [==============================] - ETA: 0s - loss: 0.2702 - acc: 0.9606
# Epoch 10: acc improved from 0.89163 to 0.96059, saving model to model\vgg16_best.h5
# 4/4 [==============================] - 33s 8s/step - loss: 0.2702 - acc: 0.9606 - val_loss: 2.2728 - val_acc: 0.8000
# Epoch 11/20
# 4/4 [==============================] - ETA: 0s - loss: 0.2586 - acc: 0.9507
# Epoch 11: acc did not improve from 0.96059
# 4/4 [==============================] - 32s 10s/step - loss: 0.2586 - acc: 0.9507 - val_loss: 1.0576 - val_acc: 0.8000
# Epoch 12/20
# 4/4 [==============================] - ETA: 0s - loss: 0.2541 - acc: 0.9261
# Epoch 12: acc did not improve from 0.96059
# 4/4 [==============================] - 33s 8s/step - loss: 0.2541 - acc: 0.9261 - val_loss: 1.0430 - val_acc: 0.8000
# Epoch 13/20
# 4/4 [==============================] - ETA: 0s - loss: 0.0819 - acc: 0.9606
# Epoch 13: acc did not improve from 0.96059
# 4/4 [==============================] - 33s 8s/step - loss: 0.0819 - acc: 0.9606 - val_loss: 1.4454 - val_acc: 0.8000
# Epoch 14/20
# 4/4 [==============================] - ETA: 0s - loss: 0.1463 - acc: 0.9655
# Epoch 14: acc improved from 0.96059 to 0.96552, saving model to model\vgg16_best.h5
# 4/4 [==============================] - 33s 8s/step - loss: 0.1463 - acc: 0.9655 - val_loss: 1.4460 - val_acc: 0.8000
# Epoch 15/20
# 4/4 [==============================] - ETA: 0s - loss: 0.0488 - acc: 0.9852
# Epoch 15: acc improved from 0.96552 to 0.98522, saving model to model\vgg16_best.h5
# 4/4 [==============================] - 33s 8s/step - loss: 0.0488 - acc: 0.9852 - val_loss: 0.8855 - val_acc: 0.8200
# Epoch 16/20
# 4/4 [==============================] - ETA: 0s - loss: 0.1362 - acc: 0.9458
# Epoch 16: acc did not improve from 0.98522
# 4/4 [==============================] - 33s 8s/step - loss: 0.1362 - acc: 0.9458 - val_loss: 1.0028 - val_acc: 0.8800
# Epoch 17/20
# 4/4 [==============================] - ETA: 0s - loss: 0.0374 - acc: 0.9754
# Epoch 17: acc did not improve from 0.98522
# 4/4 [==============================] - 33s 8s/step - loss: 0.0374 - acc: 0.9754 - val_loss: 1.4158 - val_acc: 0.8000
# Epoch 18/20
# 4/4 [==============================] - ETA: 0s - loss: 0.0898 - acc: 0.9704
# Epoch 18: acc did not improve from 0.98522
# 4/4 [==============================] - 33s 8s/step - loss: 0.0898 - acc: 0.9704 - val_loss: 1.3798 - val_acc: 0.8200
# Epoch 19/20
# 4/4 [==============================] - ETA: 0s - loss: 0.0108 - acc: 0.9951
# Epoch 19: acc improved from 0.98522 to 0.99507, saving model to model\vgg16_best.h5
# 4/4 [==============================] - 33s 8s/step - loss: 0.0108 - acc: 0.9951 - val_loss: 0.8587 - val_acc: 0.8600
# Epoch 20/20
# 4/4 [==============================] - ETA: 0s - loss: 0.0126 - acc: 0.9951
# Epoch 20: acc did not improve from 0.99507
# 4/4 [==============================] - 32s 8s/step - loss: 0.0126 - acc: 0.9951 - val_loss: 0.9455 - val_acc: 0.8800

# %% [markdown]
# ### Evaluation of Initial Model

# %%
train_result = model_vgg16.evaluate(train_ds)
val_result = model_vgg16.evaluate(val_ds)

no_augmented_df = pd.DataFrame(zip(train_result,val_result),columns=['Train','Val'],index=['Loss','Acc'])
no_augmented_df
# Out:
# 4/4 [==============================] - 24s 5s/step - loss: 0.0162 - acc: 1.0000
# 1/1 [==============================] - 7s 7s/step - loss: 0.9455 - acc: 0.8800
#          Train       Val
# Loss  0.016229  0.945539
# Acc   1.000000  0.880000

# %%
# plot learning curve
def plot_learning_curve(history):
    acc = history.history['acc']
    val_acc = history.history['val_acc']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(len(acc))

    plt.plot(epochs, acc, label='training acc')
    plt.plot(epochs, val_acc, label='validation acc')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy-%')
    plt.legend()
    plt.figure()

    plt.plot(epochs, loss, label='training loss')
    plt.plot(epochs, val_loss, label='validation loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

plot_learning_curve(history)

# %% [markdown]
# ### Adding Image Augmentation

# %%
def augmentation_generator(height,width):
    datagen = ImageDataGenerator(
            rescale=1./255.,
            width_shift_range=0.1,
            height_shift_range=0.1,
            shear_range=0.1,
            zoom_range=0.1,
            rotation_range=30,
            horizontal_flip=True,
            brightness_range=(0.5, 1.0)
            )
    aug_train_ds = datagen.flow_from_directory(
            data_dir,
            batch_size=64,
            shuffle=True,
            class_mode='binary',
            target_size=(height, width),
            classes={'no': 0., 'yes': 1.}
            )
    return aug_train_ds
aug_train_ds = augmentation_generator(height,width)
# Out:
# Found 253 images belonging to 2 classes.

# %%
fig, ax = plt.subplots(2, 4, figsize=(10, 7))
fig.suptitle("brain_tumor_pictures w/ image augmentation")
for k in range(8):
    images, labels = aug_train_ds.next()
    i, j = k//4, k%4
    ax[i, j].imshow(images[0])
    ax[i, j].set_title(f'label {int(labels[0])}')
    ax[i, j].axis('off')
plt.show()

# %% [markdown]
# ### Improved VGG16 Model

# %%
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='acc', factor=0.3,
                              patience=2, min_lr=0.0000001)
callbacks_list = [checkpoint,reduce_lr]

history = model_vgg16.fit(
        aug_train_ds,
        validation_data=val_ds,
        epochs=20, 
        verbose=True,
        callbacks=callbacks_list)
# Out:
# Epoch 1/20
# 4/4 [==============================] - ETA: 0s - loss: 0.8498 - acc: 0.8458
# Epoch 1: acc did not improve from 0.99507
# 4/4 [==============================] - 38s 10s/step - loss: 0.8498 - acc: 0.8458 - val_loss: 0.8435 - val_acc: 0.8800 - lr: 0.0100
# Epoch 2/20
# 4/4 [==============================] - ETA: 0s - loss: 0.6657 - acc: 0.8221
# Epoch 2: acc did not improve from 0.99507
# 4/4 [==============================] - 40s 10s/step - loss: 0.6657 - acc: 0.8221 - val_loss: 0.6682 - val_acc: 0.9000 - lr: 0.0100
# Epoch 3/20
# 4/4 [==============================] - ETA: 0s - loss: 0.5293 - acc: 0.8696
# Epoch 3: acc did not improve from 0.99507
# 4/4 [==============================] - 40s 10s/step - loss: 0.5293 - acc: 0.8696 - val_loss: 0.6276 - val_acc: 0.9000 - lr: 0.0100
# Epoch 4/20
# 4/4 [==============================] - ETA: 0s - loss: 0.4149 - acc: 0.8656
# Epoch 4: acc did not improve from 0.99507
# 4/4 [==============================] - 40s 10s/step - loss: 0.4149 - acc: 0.8656 - val_loss: 0.3640 - val_acc: 0.9600 - lr: 0.0100
# Epoch 5/20
# 4/4 [==============================] - ETA: 0s - loss: 0.3762 - acc: 0.8696
# Epoch 5: acc did not improve from 0.99507
# 4/4 [==============================] - 40s 10s/step - loss: 0.3762 - acc: 0.8696 - val_loss: 0.3434 - val_acc: 0.9600 - lr: 0.0100
# Epoch 6/20
# 4/4 [==============================] - ETA: 0s - loss: 0.2275 - acc: 0.9051
# Epoch 6: acc did not improve from 0.99507
# 4/4 [==============================] - 40s 10s/step - loss: 0.2275 - acc: 0.9051 - val_loss: 0.3491 - val_acc: 0.9400 - lr: 0.0030
# Epoch 7/20
# 4/4 [==============================] - ETA: 0s - loss: 0.2646 - acc: 0.9407
# Epoch 7: acc did not improve from 0.99507
# 4/4 [==============================] - 40s 11s/step - loss: 0.2646 - acc: 0.9407 - val_loss: 0.3328 - val_acc: 0.9600 - lr: 0.0030
# Epoch 8/20
# 4/4 [==============================] - ETA: 0s - loss: 0.1995 - acc: 0.9051
# Epoch 8: acc did not improve from 0.99507
# 4/4 [==============================] - 40s 11s/step - loss: 0.1995 - acc: 0.9051 - val_loss: 0.3226 - val_acc: 0.9600 - lr: 0.0030
# Epoch 9/20
# 4/4 [==============================] - ETA: 0s - loss: 0.2114 - acc: 0.9170
# Epoch 9: acc did not improve from 0.99507
# 4/4 [==============================] - 41s 11s/step - loss: 0.2114 - acc: 0.9170 - val_loss: 0.3155 - val_acc: 0.9600 - lr: 0.0030
# Epoch 10/20
# 4/4 [==============================] - ETA: 0s - loss: 0.1845 - acc: 0.9249
# Epoch 10: acc did not improve from 0.99507
# 4/4 [==============================] - 41s 11s/step - loss: 0.1845 - acc: 0.9249 - val_loss: 0.3091 - val_acc: 0.9600 - lr: 9.0000e-04
# Epoch 11/20
# 4/4 [==============================] - ETA: 0s - loss: 0.2453 - acc: 0.9209
# Epoch 11: acc did not improve from 0.99507
# 4/4 [==============================] - 41s 10s/step - loss: 0.2453 - acc: 0.9209 - val_loss: 0.3018 - val_acc: 0.9600 - lr: 9.0000e-04
# Epoch 12/20
# 4/4 [==============================] - ETA: 0s - loss: 0.1765 - acc: 0.9012
# Epoch 12: acc did not improve from 0.99507
# 4/4 [==============================] - 40s 10s/step - loss: 0.1765 - acc: 0.9012 - val_loss: 0.2989 - val_acc: 0.9600 - lr: 2.7000e-04
# Epoch 13/20
# 4/4 [==============================] - ETA: 0s - loss: 0.1701 - acc: 0.9328
# Epoch 13: acc did not improve from 0.99507
# 4/4 [==============================] - 40s 10s/step - loss: 0.1701 - acc: 0.9328 - val_loss: 0.2970 - val_acc: 0.9600 - lr: 2.7000e-04
# Epoch 14/20
# 4/4 [==============================] - ETA: 0s - loss: 0.1643 - acc: 0.9526
# Epoch 14: acc did not improve from 0.99507
# 4/4 [==============================] - 40s 10s/step - loss: 0.1643 - acc: 0.9526 - val_loss: 0.2967 - val_acc: 0.9600 - lr: 8.1000e-05
# Epoch 15/20
# 4/4 [==============================] - ETA: 0s - loss: 0.2562 - acc: 0.9051
# Epoch 15: acc did not improve from 0.99507
# 4/4 [==============================] - 40s 10s/step - loss: 0.2562 - acc: 0.9051 - val_loss: 0.2966 - val_acc: 0.9600 - lr: 8.1000e-05
# Epoch 16/20
# 4/4 [==============================] - ETA: 0s - loss: 0.2193 - acc: 0.8972
# Epoch 16: acc did not improve from 0.99507
# 4/4 [==============================] - 40s 10s/step - loss: 0.2193 - acc: 0.8972 - val_loss: 0.2962 - val_acc: 0.9600 - lr: 8.1000e-05
# Epoch 17/20
# 4/4 [==============================] - ETA: 0s - loss: 0.2311 - acc: 0.9091
# Epoch 17: acc did not improve from 0.99507
# 4/4 [==============================] - 40s 10s/step - loss: 0.2311 - acc: 0.9091 - val_loss: 0.2961 - val_acc: 0.9600 - lr: 2.4300e-05
# Epoch 18/20
# 4/4 [==============================] - ETA: 0s - loss: 0.2448 - acc: 0.9130
# Epoch 18: acc did not improve from 0.99507
# 4/4 [==============================] - 40s 10s/step - loss: 0.2448 - acc: 0.9130 - val_loss: 0.2960 - val_acc: 0.9600 - lr: 2.4300e-05
# Epoch 19/20
# 4/4 [==============================] - ETA: 0s - loss: 0.1696 - acc: 0.9526
# Epoch 19: acc did not improve from 0.99507
# 4/4 [==============================] - 40s 11s/step - loss: 0.1696 - acc: 0.9526 - val_loss: 0.2959 - val_acc: 0.9600 - lr: 7.2900e-06
# Epoch 20/20
# 4/4 [==============================] - ETA: 0s - loss: 0.1446 - acc: 0.9486
# Epoch 20: acc did not improve from 0.99507
# 4/4 [==============================] - 40s 10s/step - loss: 0.1446 - acc: 0.9486 - val_loss: 0.2959 - val_acc: 0.9600 - lr: 7.2900e-06

# %% [markdown]
# ### Evaluation of Improved Model

# %%
train_result = model_vgg16.evaluate(train_ds)
val_result = model_vgg16.evaluate(val_ds)

augmented_df = pd.DataFrame(zip(train_result,val_result),columns=['Train','Val'],index=['Loss','Acc'])
augmented_df
# Out:
# 4/4 [==============================] - 22s 5s/step - loss: 0.0011 - acc: 1.0000
# 1/1 [==============================] - 7s 7s/step - loss: 0.2959 - acc: 0.9600
#          Train      Val
# Loss  0.001059  0.29589
# Acc   1.000000  0.96000

# %%
plot_learning_curve(history)

# %%
ypred_val = model_vgg16.predict(val_ds[0][0])
ypred_val = np.array([1 if x > 0.5 else 0 for x in ypred_val])
y_val = val_ds[0][-1]

print(confusion_matrix(y_val, ypred_val))
print('\n',classification_report(ypred_val,y_val))
# Out:
# 2/2 [==============================] - 5s 2s/step
# [[18  1]
#  [ 1 30]]
#
#                precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95        19
#            1       0.97      0.97      0.97        31
#
#     accuracy                           0.96        50
#    macro avg       0.96      0.96      0.96        50
# weighted avg       0.96      0.96      0.96        50
